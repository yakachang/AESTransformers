# %%
import os
import torch

from collections import defaultdict
from transformers import AutoTokenizer, AutoModel, utils
from bertviz.transformers_neuron_view import BertModel, BertTokenizer
from bertviz import model_view
# from bertviz.neuron_view import get_attention

# %%
utils.logging.set_verbosity_error()  # Suppress standard warnings

# %%
path_to_model = os.path.join(
    "../experiments/base/ASAP/models",
    "Original/base/sets/set1/lr2e-5-b8a1-ada-fp16",
    "bert-base-cased-512-conventions-mod"
)

# %%
# text = "Hi my name is @CAPS1 @CAPS2 @PERSON1 and I'm here to talk about why I thing we should have these certain materials in the libraries.                       Why I think these materials should stay well because,  For @CAPS3 lets say its a certain movie or song or book or whatever just that one thing you were looking for, for ages and you couldn't find it in any other store and you just happening to go to the library just to look. Even though  you know its not there, but you just looking and you end up finding whatever it is you where looking for.             And what if you wanted to look for a myster book and only the library had that book you where looking for. I can think of alot of reasons why we need certain materials. well i guess that about sums that up for me.                 And in concultion put yourself in the same shoes or even my shoes. What would you do? would you let them remove those materials or would you fight for them to stay."
"""
Hi my name is @CAPS1 @CAPS2 @PERSON1 and I'm here to talk about why I thing we should have these certain materials in the libraries.
"""
text = "Hi my name is @CAPS1 @CAPS2 @PERSON1 and I'm here to talk about why I thing we should have these certain materials in the libraries."

# %%
model_type = 'bert'
model = BertModel.from_pretrained(path_to_model, output_attentions=True)  # Configure model to return attention values
tokenizer = BertTokenizer.from_pretrained(path_to_model)

# %%
# Prepare inputs to model
tokens_a = [tokenizer.cls_token] + tokenizer.tokenize(text) + [tokenizer.sep_token]
token_ids = tokenizer.convert_tokens_to_ids(tokens_a)
tokens_tensor = torch.tensor(token_ids).unsqueeze(0)
tokens_tensor
# Out:
# tensor([[  101, 20844,  1139,  1271,  1110,   137, 10184,  1475,   137, 10184,
#           1477,   137,  1825,  1475,  1105,   178,   112,   182,  1303,  1106,
#           2037,  1164,  1725,   178,  1645,  1195,  1431,  1138,  1292,  2218,
#           3881,  1107,  1103,  9818,   119,   102]])

# %%
# Call model to get attention data
model.eval()
# Out:
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(28996, 768, padding_idx=0)
#     (position_embeddings): Embedding(512, 768)
#     (token_type_embeddings): Embedding(2, 768)
#     (LayerNorm): BertLayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (1): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (2): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (3): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (4): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (5): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (6): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (7): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (8): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (9): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (10): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (11): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (activation): Tanh()
#   )
# )

# %%
output = model(tokens_tensor)
attn_data_list = output[-1]
attn_data_list
# Out:
# ({'attn': tensor([[[[4.8071e-01, 8.0965e-03, 4.5993e-03,  ..., 6.8932e-03,
#              2.1248e-02, 2.5123e-01],
#             [3.7919e-02, 1.7543e-02, 2.0456e-02,  ..., 4.0543e-02,
#              2.5979e-02, 1.5348e-02],
#             [1.2372e-02, 1.7819e-02, 8.2233e-03,  ..., 4.0908e-02,
#              4.0114e-02, 3.6282e-02],
#             ...,
#             [2.1380e-02, 1.6332e-02, 1.3302e-02,  ..., 7.0767e-02,
#              8.2557e-02, 4.2069e-02],
#             [2.3592e-02, 1.0758e-02, 5.7782e-03,  ..., 2.4473e-02,
#              1.8987e-02, 1.0775e-01],
#             [1.5904e-01, 4.7973e-03, 1.7883e-03,  ..., 2.6448e-04,
#              2.6943e-04, 7.1344e-01]],
#
#            [[3.9560e-01, 2.8550e-02, 1.7632e-02,  ..., 9.0587e-03,
#              1.2278e-02, 1.0900e-02],
#             [1.0781e-01, 1.4477e-01, 1.8125e-01,  ..., 4.9193e-04,
#             [ 0.4527, -0.0571, -0.0667,  ...,  1.9337, -0.2758,  0.0878],
#             [ 1.0305,  0.3029, -0.5913,  ...,  0.9011, -1.5038,  0.0935],
#             ...,
#             [ 1.0928, -1.5909, -0.8087,  ...,  0.1024,  0.5548,  0.1007],
#             [-0.1912, -0.5400,  0.9524,  ...,  1.2736, -1.0823, -0.8551],
#             [-0.0434, -0.3540,  0.2383,  ...,  1.3145, -0.1832, -2.4935]],
#
#            [[-1.6375, -0.7549,  0.7067,  ..., -0.0601, -0.2341, -0.0207],
#             [ 1.4505,  0.1881,  1.1619,  ...,  0.4505, -0.5813,  0.0821],
#             [ 2.1292,  2.2718,  1.5120,  ..., -0.1912,  0.7971,  0.5285],
#             ...,
#             [ 2.1881,  1.9255,  0.7350,  ...,  0.2073,  0.2402, -0.5585],
#             [ 1.2720,  0.2690,  0.1673,  ...,  0.5293, -0.3907,  1.1944],
#             [-1.7551,  0.0104,  1.3015,  ..., -0.5550,  0.6273, -0.3119]],
#
#            ...,
#
#            [[ 0.2833, -0.4154,  0.4798,  ...,  0.3600, -0.3842, -0.1447],
#             [ 0.7182,  0.6503, -0.5622,  ...,  0.6583,  0.3298,  0.1158],
#             [-0.3315, -0.2524,  0.0102,  ..., -0.8573,  1.7753,  0.2059],
#             ...,
#             [-1.0683, -0.8315, -0.0458,  ...,  1.2166,  0.5510,  1.0524],
#             [ 0.3711,  0.3033,  0.1595,  ..., -0.5833, -0.2633, -0.6278],
#             [-0.6101,  0.2280,  0.4950,  ...,  0.4805, -0.9398, -0.7347]],
#
#            [[ 1.3189, -1.3956,  0.4054,  ..., -2.2462, -0.4109, -0.1401],
#             [ 0.0707, -0.9048,  0.5436,  ..., -0.0778,  0.7966,  0.5705],
#             [ 0.9987, -0.9074, -0.5034,  ...,  0.3457,  1.2361, -0.2631],
#             ...,
#             [-0.2263,  2.1576, -1.5782,  ..., -0.7707,  0.3220, -0.8362],
#             [ 0.2261,  0.9534, -0.8203,  ..., -0.1946,  0.3083,  0.0875],
#             [ 1.7818, -0.9545, -0.6581,  ..., -2.2223,  0.1595,  0.9990]],
#
#            [[-0.6921,  0.4783,  0.3287,  ..., -1.2213, -1.1086, -0.1741],
#             [ 0.5196,  0.0229,  0.8213,  ...,  0.0806,  0.0880, -0.2445],
#             [ 1.3882,  1.7646, -1.7025,  ...,  1.0704,  0.3187, -0.1425],
#             ...,
#             [ 2.5119, -1.1142, -0.0574,  ...,  0.0134,  1.2531, -0.5666],
#             [ 1.4280,  1.1969, -1.2653,  ...,  0.7695,  0.5409, -0.6483],
#             [ 1.5198,  0.2722,  1.0223,  ...,  2.4848, -1.0782, -1.2679]]]],
#          grad_fn=<PermuteBackward0>)},
#  {'attn': tensor([[[[7.5768e-01, 2.9355e-03, 4.6915e-03,  ..., 6.2322e-03,
#              1.7334e-02, 4.3044e-02],
#             [2.1214e-01, 6.5948e-03, 2.6394e-02,  ..., 2.0936e-02,
#              3.7970e-02, 1.1835e-02],
#             [5.1486e-02, 3.0402e-02, 1.1681e-01,  ..., 2.3472e-02,
#   'keys': tensor([[[[-0.3651,  0.6438,  0.9675,  ...,  0.0921, -1.0286, -0.8556],
#             [-0.1312,  0.5458,  0.2503,  ...,  0.5963, -1.6769, -0.1598],
#             [ 0.3698,  0.0222,  0.9245,  ...,  0.7431, -1.2221, -1.0463],
#             ...,
#             [ 0.4697,  0.6786, -0.2481,  ..., -0.8898, -1.0052, -1.6366],
#             [-0.1800,  1.6866,  1.1457,  ...,  0.3125, -1.0412, -0.8368],
#             [ 0.2405, -0.1352,  1.7283,  ...,  0.3683,  0.3655, -0.1284]],
#
#            [[ 0.4103,  2.6302,  0.7937,  ..., -0.1202, -0.1837,  0.8283],
#             [ 0.2423, -0.9915, -1.3020,  ..., -2.2218, -0.7731, -1.0309],
#             [ 0.3750, -1.8948, -1.8998,  ..., -0.9089,  0.2946, -1.2930],
#             ...,
#             [-2.8891,  0.6947,  0.2261,  ..., -0.0778, -0.9467, -2.7010],
#             [-2.0619,  0.2606,  0.1189,  ..., -0.7613,  0.1115, -2.1839],
#             [-0.6304,  1.8025, -0.9290,  ..., -0.2502, -0.6377,  0.3298]],
#
#            [[-0.7153,  0.1061,  0.0838,  ...,  1.2579, -0.6241,  1.1070],
#             [-1.5327,  0.2318, -1.0681,  ..., -2.8722, -0.8730,  1.9051],
#             [-0.0581,  0.2510,  1.2670,  ..., -1.0371, -0.9224,  2.1289],
#             ...,
#             [-0.7412,  1.1309,  1.3633,  ...,  0.9480,  1.5310,  2.3784],
#             [-1.0507, -0.0765,  0.3366,  ...,  1.9829,  0.9111,  0.7497],
#             [-1.2504, -0.3686,  1.6924,  ...,  0.5051,  0.3339,  0.3965]],
#
#            ...,
#
#            [[-1.8964,  0.2572,  3.1496,  ...,  0.5660,  0.7028,  1.2473],
#             [ 0.7033, -0.5131, -0.5547,  ...,  0.3556, -1.0313,  0.1874],
#             [ 0.1155, -0.7458,  0.1100,  ..., -0.6986,  1.2536,  0.4834],
#             ...,
#             [-0.9360, -0.0484, -2.1333,  ...,  1.2782, -0.6139,  0.1208],
#             [ 0.5257, -1.6174, -0.7701,  ...,  0.0929,  0.4405, -1.1006],
#             [ 0.3559, -0.7883,  0.7026,  ...,  0.0263,  0.0764, -0.0502]],
#
#            [[-2.7229, -1.1451,  1.5285,  ...,  0.3892,  0.2309, -0.0771],
#             [ 1.5822,  0.2560, -0.6955,  ..., -1.2704,  0.1799,  0.1764],
#             [ 3.2683,  1.5704,  0.1886,  ...,  0.6272, -1.1209,  0.4729],
#             ...,
#             [ 0.2490,  0.3181, -0.8681,  ..., -0.0268, -0.1826,  3.0016],
#             [ 0.9545,  0.5231,  0.1932,  ...,  0.0399, -0.7752, -0.9081],
#             [-1.9981, -1.1934,  0.9917,  ..., -0.5572,  0.6570, -1.7630]],
#
#            [[-0.6298, -1.0829,  0.3682,  ...,  0.4566,  3.1027, -3.4000],
#             [ 1.2827,  0.3092, -3.7696,  ..., -0.6759,  0.3769,  2.1503],
#             [ 1.0350,  0.9538, -1.5036,  ..., -1.7806,  1.0076,  2.0234],
#             ...,
#             [-0.3078,  1.3078,  0.3017,  ..., -1.5639, -2.4244, -0.1746],
#             [-1.1406e+00, -4.8580e-01,  1.3706e-01,  ..., -2.4849e-01,
#               8.9107e-01, -1.4639e-01],
#             ...,
#             [-7.9574e-01, -7.3335e-01,  6.1252e-01,  ...,  2.4009e-01,
#               2.3697e-01, -1.1848e+00],
#             [ 7.3445e-01,  4.6393e-01,  1.0265e-03,  ..., -2.5439e-01,
#              -1.1756e-01, -3.4027e-02],
#             [ 1.0049e+00, -9.4410e-01,  4.4020e-01,  ...,  1.4502e-01,
#               1.6848e+00, -1.3881e+00]]]], grad_fn=<PermuteBackward0>),
#   'keys': tensor([[[[ 0.6840, -0.9342, -1.5711,  ...,  0.0762, -1.9819, -0.9300],
#             [-1.0464,  0.1767, -1.0859,  ..., -0.6152, -0.7113, -1.3946],
#             [-0.7926,  0.6401,  0.2462,  ..., -0.7225, -1.9718, -0.3725],
#             ...,
#             [ 0.4652, -1.2528, -1.3110,  ..., -2.4316,  0.5761, -2.1500],
#             [ 0.1191,  0.0128, -1.3518,  ..., -0.6557, -1.1349,  0.2079],
#             [ 0.5165, -0.8430, -0.6494,  ..., -0.5050, -1.9714, -0.3693]],
#
#            [[-0.0444,  0.4563, -0.7455,  ...,  1.0935,  0.1507,  7.1264],
#             [-0.6529,  0.8187, -0.6858,  ..., -0.3208, -0.2608, -0.7864],
#             [-2.4990,  1.1422,  0.3426,  ...,  1.4098, -0.1091,  0.3156],
#             ...,
#             [-3.6683,  0.6054,  3.0218,  ..., -1.1013,  1.9173, -1.7882],
#             [-2.2310, -0.5773,  1.0922,  ..., -1.5145,  0.7389,  2.6354],
#             [-0.3295,  0.2158, -1.8841,  ...,  0.5191, -0.3356,  6.5623]],
#
#            [[-0.1310,  0.7842, -0.3328,  ..., -0.1055,  1.6138, -0.3386],
#             [ 0.1357, -0.3820,  0.6082,  ...,  0.2069,  1.0608, -1.2986],
#             [ 0.2848,  0.1462,  1.0224,  ...,  0.7407, -0.2995, -0.5691],
#             ...,
#             [-0.0912, -0.9414,  1.4299,  ...,  1.0992,  1.3973, -0.4675],
#             [ 1.1518, -0.2694,  0.2311,  ..., -0.0273,  1.1762, -0.5179],
#             [ 0.3712, -0.0287,  0.4713,  ..., -0.2427,  0.2474, -0.5981]],
#
#            ...,
#
#            [[ 0.1962, -0.4270, -0.0725,  ..., -0.8517,  0.0973, -0.3269],
#             [ 1.0117,  1.4118, -0.8641,  ...,  0.8924,  0.3386,  2.3679],
#             [-1.1664,  2.7117,  1.0973,  ...,  0.9467,  0.2464,  2.1689],
#             ...,
#             [-1.2739, -0.8649, -0.6060,  ...,  1.4489,  1.5789, -1.9923],
#             [-0.7826, -0.0181, -0.6235,  ...,  1.0909,  1.2153,  0.2992],
#             [ 0.1392,  0.2208,  1.0588,  ..., -0.3261,  0.3476, -0.3259]],
#
#            [[ 0.9940,  2.4660, -0.0184,  ..., -0.7799,  0.7044, -0.5695],
#             [ 0.4090, -0.8121,  0.3144,  ...,  0.7797, -0.1005,  1.9764],
#             [ 1.5192,  2.1706,  0.1415,  ..., -1.0139,  2.7722,  1.0746],
#             ...,
#               1.1450e+00,  9.2748e-01],
#             [-1.9866e+00, -8.0352e-01, -3.3591e+00,  ...,  2.7762e+00,
#               4.0193e-01, -3.6149e-01],
#             [-2.1517e+00,  9.0829e-01, -3.4474e+00,  ...,  3.2679e+00,
#               8.4376e-01,  7.1264e-01],
#             ...,
#             [-1.2366e+00,  2.6410e+00, -2.1226e+00,  ...,  2.5847e+00,
#               9.1479e-01, -9.2185e-01],
#             [-1.6724e+00,  2.0045e+00, -2.0908e+00,  ...,  3.7821e+00,
#               8.3962e-01, -5.5615e-01],
#             [ 5.5097e-01, -1.2330e+00,  1.0330e+00,  ..., -1.7148e+00,
#              -1.3430e-01, -4.4208e-01]],
#
#            ...,
#
#            [[-5.8688e-01,  2.1580e-01,  1.3577e+00,  ...,  8.6581e-01,
#               8.9992e-01,  3.6595e-01],
#             [-1.6988e+00,  2.0862e+00,  1.1889e+00,  ...,  2.8129e-01,
#               9.0371e-01,  6.5494e-01],
#             [-1.3766e+00,  1.8686e+00,  2.1462e+00,  ...,  7.1014e-01,
#               1.1312e+00, -1.4561e-01],
#             ...,
#             [ 1.5969e-01,  1.1570e-01,  1.6868e+00,  ...,  6.1603e-01,
#               3.4116e-01, -1.0519e+00],
#             [-1.1231e+00,  6.1443e-01,  2.4936e+00,  ...,  8.9097e-01,
#               1.0987e+00,  1.4258e+00],
#             [ 3.4386e-01,  2.0830e-01, -2.9955e-01,  ..., -1.5287e-01,
#              -5.8364e-01, -2.6599e-01]],
#
#            [[-8.9534e-03,  5.2949e-01,  8.7297e-01,  ..., -1.2582e+00,
#              -2.6229e-01, -1.5895e-01],
#             [-1.0159e+00,  5.5509e-01, -3.5147e-01,  ..., -1.1080e+00,
#              -8.0928e-01,  3.6728e-01],
#             [-1.4486e+00,  3.2072e-01,  3.0579e-01,  ..., -1.5388e+00,
#              -3.8124e-01,  6.8233e-01],
#             ...,
#             [-1.8480e+00, -8.0332e-02,  2.3200e-01,  ...,  1.1536e-01,
#              -1.1279e+00,  1.9511e+00],
#             [-3.6536e-01,  1.1733e-01,  1.0064e+00,  ..., -8.5988e-01,
#               2.5576e-01, -7.1639e-02],
#             [-3.4319e-01, -1.3605e-01, -2.8650e-01,  ...,  4.9795e-01,
#              -2.6500e-01, -7.6525e-01]],
#
#            [[-8.2412e-01,  2.1817e+00, -3.3341e-01,  ...,  1.2691e+00,
#               8.1171e-01,  1.2036e+00],
#             [ 3.7671e-02, -1.1268e-01,  5.9793e-01,  ...,  6.3123e-01,
#               8.4937e-01,  3.4164e-01],
#             [ 1.7411e-01,  7.7506e-01, -6.9465e-01,  ...,  8.2755e-01,
#               1.7003e+00,  1.1918e+00],
#             ...,
#             [ 9.1012e-02, -1.0478e-01, -6.9570e-01,  ..., -1.2590e-01,
#              -4.6816e-01,  1.7364e+00],
#             [ 5.7753e-01,  1.1268e+00, -1.5409e+00,  ...,  3.8034e-02,
#               8.6469e-01,  1.8486e+00],
#             [-1.7505e-02, -4.6363e-01,  2.3532e-01,  ..., -2.3843e-01,
#              -1.6726e-01, -1.5409e+00]]]], grad_fn=<PermuteBackward0>)})

# %%
# Populate map with attn data and, optionally, query, key data
attn_dict = defaultdict(list)

# %%
print(f"Num of Tokens: {len(tokens_a)}")
print(f"Num of Layers: {len(attn_data_list)}")

for layer, attn_data in enumerate(attn_data_list):
    # Process attention
    attn = attn_data['attn'][0]  # assume batch_size=1; shape = [num_heads, source_seq_len, target_seq_len]
    attn_dict['all'].append(attn.tolist())
    print(len(attn.tolist()))
    print(len(attn.tolist()[0]))
    print(len(attn.tolist()[0][0]))
    break
# Out:
# Num of Tokens: 36
# Num of Layers: 12
# 12
# 36
# 36

# %%
for layer, attn_data in enumerate(attn_data_list):
    # Process attention
    attn = attn_data['attn'][0]  # assume batch_size=1; shape = [num_heads, source_seq_len, target_seq_len]
    attn_dict['all'].append(attn.tolist())
    # print(len(attn.tolist()[0]))
    # print(len(attn.tolist()[0][0]))
    print(f"layer: {layer}")
    print("-" * 100)
    for head in range(len(attn)):
        for i in range(len(tokens_a)):

            if tokens_a[i] in ["[CLS]", "[SEP]"]:
                continue

            max_weight_local = 0
            max_tokens_local = defaultdict(list)
            for j in range(len(tokens_a)):
                if attn.tolist()[head][i][j] > max_weight_local:
                    if tokens_a[j] not in ["[CLS]", "[SEP]"]:
                        max_weight_local = attn.tolist()[head][i][j]
                        max_tokens_local[max_weight_local].append(tokens_a[j])

                # break
            if max_weight_local >= 0.98:
                print(
                    f"layer: {layer}, ",
                    f"head: {head}, "
                    f"token_left: {tokens_a[i]}, ",
                    f"token_right: {max_tokens_local[max_weight_local]}, ",
                    f"attention_wight: {round(max_weight_local, 4)}")
            # break
        # break

    print("-" * 100)
    # break
# Out:
# layer: 0
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# layer: 1
# ----------------------------------------------------------------------------------------------------
# layer: 1,  head: 3, token_left: talk,  token_right: ['about'],  attention_wight: 0.9956
# layer: 1,  head: 4, token_left: is,  token_right: ['name'],  attention_wight: 0.9911
# layer: 1,  head: 4, token_left: and,  token_right: ['##1'],  attention_wight: 0.9853
# layer: 1,  head: 4, token_left: ',  token_right: ['i'],  attention_wight: 0.9977
# layer: 1,  head: 4, token_left: here,  token_right: ['m'],  attention_wight: 0.9823
# layer: 1,  head: 4, token_left: to,  token_right: ['here'],  attention_wight: 0.9895
# layer: 1,  head: 4, token_left: talk,  token_right: ['to'],  attention_wight: 0.9951
# layer: 1,  head: 4, token_left: about,  token_right: ['talk'],  attention_wight: 0.9971
# layer: 1,  head: 4, token_left: thing,  token_right: ['i'],  attention_wight: 0.9898
# layer: 1,  head: 4, token_left: the,  token_right: ['in'],  attention_wight: 0.9976
# layer: 1,  head: 11, token_left: hi,  token_right: ['my'],  attention_wight: 0.9951
# layer: 1,  head: 11, token_left: my,  token_right: ['name'],  attention_wight: 0.9996
# layer: 1,  head: 11, token_left: name,  token_right: ['is'],  attention_wight: 0.9992
# layer: 1,  head: 11, token_left: is,  token_right: ['@'],  attention_wight: 0.9952
# layer: 1,  head: 11, token_left: caps,  token_right: ['##1'],  attention_wight: 0.9885
# layer: 1,  head: 11, token_left: ##1,  token_right: ['@'],  attention_wight: 0.9959
# layer: 1,  head: 11, token_left: ##2,  token_right: ['@'],  attention_wight: 0.9994
# layer: 1,  head: 11, token_left: person,  token_right: ['##1'],  attention_wight: 0.9934
# layer: 1,  head: 11, token_left: ##1,  token_right: ['and'],  attention_wight: 0.9998
# layer: 1,  head: 11, token_left: and,  token_right: ['i'],  attention_wight: 0.9999
# layer: 1,  head: 11, token_left: i,  token_right: ["'"],  attention_wight: 0.9981
# layer: 1,  head: 11, token_left: ',  token_right: ['m'],  attention_wight: 0.9999
# layer: 1,  head: 11, token_left: m,  token_right: ['here'],  attention_wight: 0.9997
# layer: 1,  head: 11, token_left: here,  token_right: ['to'],  attention_wight: 0.9995
# layer: 1,  head: 11, token_left: to,  token_right: ['talk'],  attention_wight: 0.9995
# layer: 1,  head: 11, token_left: talk,  token_right: ['about'],  attention_wight: 0.9999
# layer: 1,  head: 11, token_left: about,  token_right: ['why'],  attention_wight: 0.9989
# layer: 1,  head: 11, token_left: why,  token_right: ['i'],  attention_wight: 0.9984
# layer: 1,  head: 11, token_left: i,  token_right: ['thing'],  attention_wight: 0.9947
# layer: 1,  head: 11, token_left: thing,  token_right: ['we'],  attention_wight: 0.9984
# layer: 1,  head: 11, token_left: we,  token_right: ['should'],  attention_wight: 0.999
# layer: 1,  head: 11, token_left: should,  token_right: ['have'],  attention_wight: 0.9992
# layer: 1,  head: 11, token_left: have,  token_right: ['these'],  attention_wight: 0.9998
# layer: 1,  head: 11, token_left: these,  token_right: ['certain'],  attention_wight: 0.9988
# layer: 1,  head: 11, token_left: certain,  token_right: ['materials'],  attention_wight: 0.9948
# layer: 1,  head: 11, token_left: in,  token_right: ['the'],  attention_wight: 0.9986
# layer: 1,  head: 11, token_left: the,  token_right: ['libraries'],  attention_wight: 0.9969
# ----------------------------------------------------------------------------------------------------
# layer: 2
# ----------------------------------------------------------------------------------------------------
# layer: 2,  head: 3, token_left: hi,  token_right: ['my'],  attention_wight: 1.0
# layer: 2,  head: 3, token_left: my,  token_right: ['name'],  attention_wight: 1.0
# layer: 2,  head: 3, token_left: name,  token_right: ['is'],  attention_wight: 1.0
# layer: 2,  head: 3, token_left: is,  token_right: ['@'],  attention_wight: 0.9999
# layer: 2,  head: 3, token_left: @,  token_right: ['caps'],  attention_wight: 1.0
# layer: 2,  head: 3, token_left: caps,  token_right: ['##1'],  attention_wight: 0.9998
# layer: 2,  head: 3, token_left: ##1,  token_right: ['@'],  attention_wight: 1.0
# layer: 2,  head: 3, token_left: @,  token_right: ['caps'],  attention_wight: 1.0
# layer: 2,  head: 3, token_left: caps,  token_right: ['##2'],  attention_wight: 1.0
# layer: 2,  head: 3, token_left: ##2,  token_right: ['@'],  attention_wight: 1.0
# layer: 2,  head: 3, token_left: @,  token_right: ['person'],  attention_wight: 1.0
# layer: 2,  head: 3, token_left: person,  token_right: ['##1'],  attention_wight: 1.0
# layer: 2,  head: 3, token_left: ##1,  token_right: ['and'],  attention_wight: 1.0
# layer: 2,  head: 3, token_left: and,  token_right: ['i'],  attention_wight: 0.9996
# layer: 2,  head: 3, token_left: i,  token_right: ["'"],  attention_wight: 1.0
# layer: 2,  head: 3, token_left: ',  token_right: ['m'],  attention_wight: 1.0
# layer: 2,  head: 3, token_left: m,  token_right: ['here'],  attention_wight: 1.0
# layer: 2,  head: 3, token_left: here,  token_right: ['to'],  attention_wight: 1.0
# layer: 2,  head: 3, token_left: to,  token_right: ['talk'],  attention_wight: 1.0
# layer: 2,  head: 3, token_left: talk,  token_right: ['about'],  attention_wight: 1.0
# layer: 2,  head: 3, token_left: about,  token_right: ['why'],  attention_wight: 0.9998
# layer: 2,  head: 3, token_left: why,  token_right: ['i'],  attention_wight: 1.0
# layer: 2,  head: 3, token_left: i,  token_right: ['thing'],  attention_wight: 0.9998
# layer: 2,  head: 3, token_left: thing,  token_right: ['we'],  attention_wight: 1.0
# layer: 2,  head: 3, token_left: we,  token_right: ['should'],  attention_wight: 1.0
# layer: 2,  head: 3, token_left: should,  token_right: ['have'],  attention_wight: 1.0
# layer: 2,  head: 3, token_left: have,  token_right: ['these'],  attention_wight: 1.0
# layer: 2,  head: 3, token_left: these,  token_right: ['certain'],  attention_wight: 1.0
# layer: 2,  head: 3, token_left: certain,  token_right: ['materials'],  attention_wight: 1.0
# layer: 2,  head: 3, token_left: materials,  token_right: ['in'],  attention_wight: 1.0
# layer: 2,  head: 3, token_left: in,  token_right: ['the'],  attention_wight: 1.0
# layer: 2,  head: 3, token_left: the,  token_right: ['libraries'],  attention_wight: 1.0
# layer: 2,  head: 3, token_left: libraries,  token_right: ['.'],  attention_wight: 1.0
# ----------------------------------------------------------------------------------------------------
# layer: 3
# ----------------------------------------------------------------------------------------------------
# layer: 3,  head: 11, token_left: my,  token_right: ['hi'],  attention_wight: 0.9994
# layer: 3,  head: 11, token_left: name,  token_right: ['my'],  attention_wight: 0.9999
# layer: 3,  head: 11, token_left: is,  token_right: ['name'],  attention_wight: 0.9994
# layer: 3,  head: 11, token_left: @,  token_right: ['is'],  attention_wight: 0.9992
# layer: 3,  head: 11, token_left: caps,  token_right: ['@'],  attention_wight: 1.0
# layer: 3,  head: 11, token_left: ##1,  token_right: ['caps'],  attention_wight: 0.9999
# layer: 3,  head: 11, token_left: @,  token_right: ['##1'],  attention_wight: 0.9988
# layer: 3,  head: 11, token_left: caps,  token_right: ['@'],  attention_wight: 1.0
# layer: 3,  head: 11, token_left: ##2,  token_right: ['caps'],  attention_wight: 0.9999
# layer: 3,  head: 11, token_left: @,  token_right: ['##2'],  attention_wight: 0.9999
# layer: 3,  head: 11, token_left: person,  token_right: ['@'],  attention_wight: 0.9999
# layer: 3,  head: 11, token_left: ##1,  token_right: ['person'],  attention_wight: 0.9999
# layer: 3,  head: 11, token_left: and,  token_right: ['##1'],  attention_wight: 0.99
# layer: 3,  head: 11, token_left: i,  token_right: ['and'],  attention_wight: 0.9959
# layer: 3,  head: 11, token_left: ',  token_right: ['i'],  attention_wight: 1.0
# layer: 3,  head: 11, token_left: m,  token_right: ["'"],  attention_wight: 1.0
# layer: 3,  head: 11, token_left: here,  token_right: ['m'],  attention_wight: 0.9997
# layer: 3,  head: 11, token_left: to,  token_right: ['here'],  attention_wight: 0.9998
# layer: 3,  head: 11, token_left: talk,  token_right: ['to'],  attention_wight: 0.9933
# layer: 3,  head: 11, token_left: about,  token_right: ['talk'],  attention_wight: 0.9996
# layer: 3,  head: 11, token_left: why,  token_right: ['about'],  attention_wight: 0.9982
# layer: 3,  head: 11, token_left: i,  token_right: ['why'],  attention_wight: 0.9887
# layer: 3,  head: 11, token_left: thing,  token_right: ['i'],  attention_wight: 1.0
# layer: 3,  head: 11, token_left: we,  token_right: ['thing'],  attention_wight: 0.9976
# layer: 3,  head: 11, token_left: should,  token_right: ['we'],  attention_wight: 0.9964
# layer: 3,  head: 11, token_left: have,  token_right: ['should'],  attention_wight: 0.9958
# layer: 3,  head: 11, token_left: these,  token_right: ['have'],  attention_wight: 0.9967
# layer: 3,  head: 11, token_left: certain,  token_right: ['these'],  attention_wight: 0.9998
# layer: 3,  head: 11, token_left: materials,  token_right: ['certain'],  attention_wight: 0.9971
# layer: 3,  head: 11, token_left: in,  token_right: ['materials'],  attention_wight: 0.9989
# layer: 3,  head: 11, token_left: the,  token_right: ['in'],  attention_wight: 0.9992
# layer: 3,  head: 11, token_left: libraries,  token_right: ['the'],  attention_wight: 0.998
# ----------------------------------------------------------------------------------------------------
# layer: 4
# ----------------------------------------------------------------------------------------------------
# layer: 4,  head: 0, token_left: caps,  token_right: ['caps'],  attention_wight: 0.9921
# layer: 4,  head: 0, token_left: caps,  token_right: ['caps'],  attention_wight: 0.9809
# ----------------------------------------------------------------------------------------------------
# layer: 5
# ----------------------------------------------------------------------------------------------------
# layer: 5,  head: 1, token_left: my,  token_right: ['hi'],  attention_wight: 0.9958
# layer: 5,  head: 1, token_left: name,  token_right: ['my'],  attention_wight: 0.9989
# layer: 5,  head: 1, token_left: is,  token_right: ['name'],  attention_wight: 0.9985
# layer: 5,  head: 1, token_left: @,  token_right: ['is'],  attention_wight: 0.9834
# layer: 5,  head: 1, token_left: caps,  token_right: ['@'],  attention_wight: 0.9997
# layer: 5,  head: 1, token_left: ##1,  token_right: ['caps'],  attention_wight: 0.9995
# layer: 5,  head: 1, token_left: @,  token_right: ['##1'],  attention_wight: 0.9982
# layer: 5,  head: 1, token_left: caps,  token_right: ['@'],  attention_wight: 0.9997
# layer: 5,  head: 1, token_left: ##2,  token_right: ['caps'],  attention_wight: 0.996
# layer: 5,  head: 1, token_left: @,  token_right: ['##2'],  attention_wight: 0.9959
# layer: 5,  head: 1, token_left: person,  token_right: ['@'],  attention_wight: 0.9971
# layer: 5,  head: 1, token_left: ##1,  token_right: ['person'],  attention_wight: 0.9971
# layer: 5,  head: 1, token_left: and,  token_right: ['##1'],  attention_wight: 0.9951
# layer: 5,  head: 1, token_left: ',  token_right: ['i'],  attention_wight: 0.9985
# layer: 5,  head: 1, token_left: to,  token_right: ['here'],  attention_wight: 0.9997
# layer: 5,  head: 1, token_left: talk,  token_right: ['to'],  attention_wight: 0.9986
# layer: 5,  head: 1, token_left: about,  token_right: ['talk'],  attention_wight: 0.9963
# layer: 5,  head: 1, token_left: i,  token_right: ['why'],  attention_wight: 0.9806
# layer: 5,  head: 1, token_left: thing,  token_right: ['i'],  attention_wight: 0.9993
# layer: 5,  head: 1, token_left: we,  token_right: ['thing'],  attention_wight: 0.9859
# layer: 5,  head: 1, token_left: these,  token_right: ['have'],  attention_wight: 0.9904
# layer: 5,  head: 1, token_left: in,  token_right: ['materials'],  attention_wight: 0.9908
# ----------------------------------------------------------------------------------------------------
# layer: 6
# ----------------------------------------------------------------------------------------------------
# layer: 6,  head: 1, token_left: my,  token_right: ['hi'],  attention_wight: 0.9992
# layer: 6,  head: 1, token_left: @,  token_right: ['is'],  attention_wight: 0.9958
# layer: 6,  head: 1, token_left: caps,  token_right: ['@'],  attention_wight: 0.9859
# layer: 6,  head: 1, token_left: ##2,  token_right: ['caps'],  attention_wight: 0.9829
# layer: 6,  head: 1, token_left: person,  token_right: ['@'],  attention_wight: 0.9994
# layer: 6,  head: 1, token_left: ##1,  token_right: ['person'],  attention_wight: 0.998
# layer: 6,  head: 1, token_left: thing,  token_right: ['i'],  attention_wight: 0.9987
# layer: 6,  head: 1, token_left: the,  token_right: ['in'],  attention_wight: 0.9859
# layer: 6,  head: 9, token_left: hi,  token_right: ['my'],  attention_wight: 0.9994
# layer: 6,  head: 9, token_left: my,  token_right: ['name'],  attention_wight: 0.9999
# layer: 6,  head: 9, token_left: is,  token_right: ['@'],  attention_wight: 0.998
# layer: 6,  head: 9, token_left: @,  token_right: ['caps'],  attention_wight: 0.9988
# layer: 6,  head: 9, token_left: caps,  token_right: ['##1'],  attention_wight: 0.9982
# layer: 6,  head: 9, token_left: ##1,  token_right: ['@'],  attention_wight: 0.9998
# layer: 6,  head: 9, token_left: @,  token_right: ['caps'],  attention_wight: 0.9901
# layer: 6,  head: 9, token_left: caps,  token_right: ['##2'],  attention_wight: 0.9958
# layer: 6,  head: 9, token_left: ##2,  token_right: ['@'],  attention_wight: 0.9869
# layer: 6,  head: 9, token_left: @,  token_right: ['person'],  attention_wight: 0.9988
# layer: 6,  head: 9, token_left: person,  token_right: ['##1'],  attention_wight: 0.9998
# layer: 6,  head: 9, token_left: and,  token_right: ['i'],  attention_wight: 0.9939
# layer: 6,  head: 9, token_left: ',  token_right: ['m'],  attention_wight: 0.9919
# layer: 6,  head: 9, token_left: m,  token_right: ['here'],  attention_wight: 0.9929
# layer: 6,  head: 9, token_left: here,  token_right: ['to'],  attention_wight: 0.9937
# layer: 6,  head: 9, token_left: to,  token_right: ['talk'],  attention_wight: 0.9997
# layer: 6,  head: 9, token_left: talk,  token_right: ['about'],  attention_wight: 0.9949
# layer: 6,  head: 9, token_left: about,  token_right: ['why'],  attention_wight: 0.9943
# layer: 6,  head: 9, token_left: why,  token_right: ['i'],  attention_wight: 0.9957
# layer: 6,  head: 9, token_left: should,  token_right: ['have'],  attention_wight: 0.9873
# layer: 6,  head: 9, token_left: have,  token_right: ['these'],  attention_wight: 0.9936
# layer: 6,  head: 9, token_left: certain,  token_right: ['materials'],  attention_wight: 0.9922
# layer: 6,  head: 9, token_left: in,  token_right: ['the'],  attention_wight: 0.999
# layer: 6,  head: 9, token_left: the,  token_right: ['libraries'],  attention_wight: 0.9955
# ----------------------------------------------------------------------------------------------------
# layer: 7
# ----------------------------------------------------------------------------------------------------
# layer: 7,  head: 0, token_left: my,  token_right: ['hi'],  attention_wight: 0.9994
# ----------------------------------------------------------------------------------------------------
# layer: 8
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# layer: 9
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# layer: 10
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# layer: 11
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------

# %%
for layer, attn_data in enumerate(attn_data_list):
    # Process attention
    attn = attn_data['attn'][0]  # assume batch_size=1; shape = [num_heads, source_seq_len, target_seq_len]
    attn_dict['all'].append(attn.tolist())

# %%
def format_special_chars(tokens):
    return [t.replace('Ġ', ' ').replace('▁', ' ') for t in tokens]

# %%
tokens_a = format_special_chars(tokens_a)
tokens_a
# Out:
# ['[CLS]',
#  'hi',
#  'my',
#  'name',
#  'is',
#  '@',
#  'caps',
#  '##1',
#  '@',
#  'caps',
#  '##2',
#  '@',
#  'person',
#  '##1',
#  'and',
#  'i',
#  "'",
#  'm',
#  'here',
#  'to',
#  'talk',
#  'about',
#  'why',
#  'i',
#  'thing',
#  'we',
#  'should',
#  'have',
#  'these',
#  'certain',
#  'materials',
#  'in',
#  'the',
#  'libraries',
#  '.',
#  '[SEP]']

# %%
results = {
    'all': {
        'attn': attn_dict['all'],
        'left_text': tokens_a,
        'right_text': tokens_a
    }
}
